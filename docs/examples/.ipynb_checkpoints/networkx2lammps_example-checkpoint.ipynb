# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import networkx as nx
import numpy as np
import scipy.spatial.distance

from graph2lammps.convert import gen_pos, write_pdb, write_lammps

# %%
def generate_dendrimer(branching_factor, generations):
    G = nx.Graph()

    def add_branches(parent, depth):
        if depth == 0:
            return

        for i in range(branching_factor):
            child = parent * branching_factor + i + 1
            G.add_node(child)
            G.add_edge(parent, child)
            add_branches(child, depth - 1)

    root = 0
    G.add_node(root)
    for i in range(branching_factor):
        child = root * branching_factor + i + 1
        G.add_node(child)
        G.add_edge(root, child)
        add_branches(child, generations - 1)

    return G



branching_factor = 3
generations = 3

G = generate_dendrimer(branching_factor, generations)

nx.draw(G, pos=nx.kamada_kawai_layout(G))

for node in G.nodes():
    G.nodes[node]['type'] = random.randint(1, 2)
    G.nodes[node]['name'] = string.ascii_uppercase[G.nodes[node]['type'] ]
    
for edge in G.edges():
    G.edges[edge]['type'] = np.random.randint(1, 2)
    
pos = gen_pos(G, rmin=0.5, bdist=1.0, bmin=0.9, bmax=1.1, niter=1000)

G.graph['mass'] = {1: 1, 2:2}
# Out:
# # Significant overlaps or bad bonds detected. Attempting pushoff step 1
# # Significant overlaps or bad bonds detected. Attempting pushoff step 51
# # No substantial overlaps or bad bonds found after 52 steps...

# %%
write_lammps(G, pos, fname='sys.data')
